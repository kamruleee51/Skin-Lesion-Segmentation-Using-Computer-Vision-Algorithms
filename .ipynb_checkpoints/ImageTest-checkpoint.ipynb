# %%
import os,glob,cv2
from keras.applications.vgg16 import preprocess_input
import numpy as np
# Out:
# C:\Users\kamru\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
CurrentDirectory=os.getcwd()
Image=CurrentDirectory+'/data/TrainImage2/'
GT=CurrentDirectory+'/data/TrainGT2/'

# %%
img = glob.glob(Image+"*.png")
img.sort()
# print(img)
gt = glob.glob(GT+"*.png")
gt.sort()
# print(gt)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
im=cv2.imread(img[10],-1)
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(preprocess_input(im), cv2.COLOR_BGR2RGB))
print(im.shape)
M=np.dstack((im, im))
im = np.rollaxis(M, 2, 0)
print(im.shape)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (767, 1022, 3)
# (6, 767, 1022)
